# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import os
from PIL import Image

print("All imports successful")
# Out:
# All imports successful

# %%
# load labels
df = pd.read_csv('../data/train.csv')

print(f"Dataset shape: {df.shape}")
print(f"\nFirst few rows:")
print(df.head())
print(f"\nClass distribution:")
print(df['diagnosis'].value_counts().sort_index())
# Out:
# Dataset shape: (3662, 2)
#
# First few rows:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0
#
# Class distribution:
# diagnosis
# 0    1805
# 1     370
# 2     999
# 3     193
# 4     295
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 5, figsize=(20, 4))

for grade in range(5):
    sample = df[df['diagnosis'] == grade].iloc[0]
    img_path = f'../data/train_images/{sample["id_code"]}.png'
    
    img = Image.open(img_path)
    
    axes[grade].imshow(img)
    axes[grade].set_title(f'Grade {grade}\n{grade_names[grade]}', 
                          fontsize=11)
    axes[grade].axis('off')

plt.suptitle('Sample fundus images — one per severity grade', fontsize=13)
plt.tight_layout()
plt.show()

# %%
import os

# check what's in the data folder
print("Contents of data/:")
for item in os.listdir('../data/'):
    print(f"  {item}")

# check what's inside the train folder if it exists
train_path = '../data/train'
if os.path.exists(train_path):
    files = os.listdir(train_path)
    print(f"\nContents of data/train/ (first 5):")
    for f in files[:5]:
        print(f"  {f}")
    print(f"  ... ({len(files)} total files)")
else:
    print("\ndata/train/ folder not found")
# Out:
# Contents of data/:
#   sample_submission.csv
#   test.csv
#   test_images
#   train.csv
#   train_images
#
# data/train/ folder not found
